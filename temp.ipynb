# %% [markdown]
# # IBM Watson Account
# I dont want to provide them with my credit card information so I hosted a projected on github instead.

# %% [markdown]
# Here some python code as an example

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt

# %% [markdown]
# Also, here's a list
#  - oen
#  - two
#  - three
