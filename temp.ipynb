# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Richard Roberts**

# %% [markdown]
# Occupation: Stay-At-Home Dad

# %% [markdown]
# *I dont want to provide them with my credit card information so I hosted a projected on github instead. I'm interested in data science because I want to utilize the power of AI!*

# %% [markdown]
# ### This code imports several different common python libraries used for data science.

# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation

# %% [markdown]
# Also, here's a list
#  - oen
#  - two
#  - three
#
# Here's a hyperlink
# [Markdown Tutorial](https://riptutorial.com/markdown/example/1779/inline-link)
#
#
# Here's a meme
# ![Wizard](https://assets.rbl.ms/13915425/980x.jpg)
